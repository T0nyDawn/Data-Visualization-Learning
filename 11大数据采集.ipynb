# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as  plt
import xlrd

# %%
data = pd.read_excel(r"D:\八爪鱼采集数据\京东-商品搜索.xlsx")
data
# Out:
#     搜索关键词                                               商品名称           商品SKU  \
# 0      李宁  李宁短袖T恤男装夏季新款潮流圆领男士上衣半袖衫宽松透气运动跑步快干衣 843-2标准白(棉料...     65637332360
# 1      李宁  李宁t恤短袖男女夏季新款国潮印花白色棉潮流休闲体恤健身跑步时尚半袖文化衫 标准白(店长推荐)...  10044471896424
# 2      李宁  李宁男鞋板鞋夏季透气低帮情侣经典小白鞋潮流滑板鞋运动休闲鞋男 鲨鱼灰/标准白 42\n\t\...  10051278976112
# 3      李宁  中国李宁短袖t恤男情侣款夏季新品棉质圆领宽松女体恤休闲篮球跑步上衣文化衫 【店长推荐】白色(...  10032081898801
# 4      李宁  【新品】李宁音速9TD篮球鞋男樱花粉2022中低帮实战10缓震耐磨男鞋运动鞋男 樱花粉/冰激...  10032146320986
# ..    ...                                                ...             ...
# 235    李宁  李宁【两只装】健身手套男女运动骑行护具半指训练引体向上撸铁器械单杠锻炼防滑防护女士耐磨护手掌...    100003113769
# 236    李宁  【速干科技】李宁运动裤七分裤男士训练系列短裤梭织舒适健身裤子官方旗舰网AKQQ025 新标准...     68630856865
# 237    李宁  京东超市\t\n李宁护踝【升级两只装】男女运动护脚踝护具扭伤脚踝固定关节支具篮球护脚腕踝套绷...    100026208838
# 238    李宁  李宁运动裤男训练系列健身服舒适透气修身休闲长裤子AKLQ031 新标准黑-1 XL\n\t\...     65478994882
# 239    李宁  【音速10】李宁篮球鞋男2022新品春夏Team回弹篮球场地鞋运动鞋鞋子官方旗舰网ABPS0...  10046249295472
#
# ...

# %%
x=data.评价人数
y=data.价格
z=data.搜索关键词

# %%
plt.rcParams["font.sans-serif"]=["SimHei"]
plt.rcParams["axes.unicode_minus"]=False
fig=plt.figure()
ax=fig.add_subplot(111)
ax.plot(y)
ax.set_ylabel('李宁的商品价格')
ax.set_xlabel('各个商品')
ax.set_title('李宁的商品价格集中趋势')
plt.show()

# %%
plt.rcParams["font.sans-serif"]=["SimHei"]
plt.rcParams["axes.unicode_minus"]=False
fig=plt.figure()
ax=fig.add_subplot(111)
ax.plot(x)
ax.set_ylabel('各个商品评论数')
ax.set_xlabel('各个商品')
ax.set_title('李宁的商品评论数集中趋势')
plt.show()

# %%
value1=data[data.价格>90]
vc1=value1.count()
# Out:
# 搜索关键词    191
# 商品名称     191
# 商品SKU    191
# 商品链接     191
# 封面图链接    103
# 价格       191
# 评价人数     191
# 评论链接     191
# 商家店名     191
# 店铺链接     191
# 标签       186
# 是否广告     191
# 页码       191
# 当前时间     191
# 页面网址     191
# dtype: int64

# %%
value2=data[data.价格<60]
vc2=value2.count()
vc2
# Out:
# 搜索关键词    38
# 商品名称     38
# 商品SKU    38
# 商品链接     38
# 封面图链接    24
# 价格       38
# 评价人数     38
# 评论链接     38
# 商家店名     38
# 店铺链接     38
# 标签       38
# 是否广告     38
# 页码       38
# 当前时间     38
# 页面网址     38
# dtype: int64

# %%
vc3=240-38-191
vc3
# Out:
# 11

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(data=np.array([38,11,191]), index=['李宁的价格小于60的商品数量', '李宁的价格在60和90之间的商品数量', '李宁的价格小于60的商品数量'], columns=['李宁商品价格分布'])
df.plot.pie(subplots=True)
# Out:
# array([<AxesSubplot:ylabel='李宁商品价格分布'>], dtype=object)

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(data.价格)
df.plot.box()
# Out:
# <AxesSubplot:>

# %%
data.价格.describe()
# Out:
# count     240.000000
# mean      234.492500
# std       201.834799
# min        17.800000
# 25%        99.000000
# 50%       173.500000
# 75%       261.500000
# max      1299.000000
# Name: 价格, dtype: float64

# %%
data.dtypes
# Out:
# 搜索关键词     object
# 商品名称      object
# 商品SKU      int64
# 商品链接      object
# 封面图链接     object
# 价格        object
# 评价人数      object
# 评论链接      object
# 商家店名      object
# 店铺链接      object
# 标签        object
# 是否广告      object
# 页码       float64
# 当前时间      object
# 页面网址      object
# dtype: object

# %%
data.head()
# Out:
#   搜索关键词                                               商品名称           商品SKU  \
# 0   跑步鞋  特步男鞋运动鞋子男夏季网面鞋透气减震新款跑步鞋跑鞋休闲鞋男运动鞋包 白灰绿 42\n\t\t...  10030884795783
# 1   跑步鞋  鸿星尔克男鞋红星运动鞋男2022春夏季新款飞织透气网面皮革防水保暖舒适男士跑步鞋学生潮流休闲...  10028835246963
# 2   跑步鞋  【氢风科技】特步男鞋运动鞋子男夏季新款跑步鞋透气网面飞织潮流男士旅游防滑耐磨健身训练网鞋休闲...  10044043233367
# 3   跑步鞋  线下同款\t\n【销量过万】安踏男鞋运动鞋男士2022夏季网面透气跑步鞋休闲板鞋户外鞋厚底慢...  10030159513111
# 4   跑步鞋  岁漫轩跑步鞋男鞋夏季透气网面飞织网鞋莆田减震飞马37登月38休闲运动鞋男 白彩虹 42\n\...  10047133270162
#
#                                       商品链接  \
# 0  https://item.jd.com/10030884795783.html
# 1  https://item.jd.com/10028835246963.html
# 2  https://item.jd.com/10044043233367.html
# 3  https://item.jd.com/10030159513111.html
# 4  https://item.jd.com/10047133270162.html
#
#                                                封面图链接      价格   评价人数  \
# 0  https://img13.360buyimg.com/n7/jfs/t1/192406/3...  139.00    5万+
# 1  https://img13.360buyimg.com/n7/jfs/t1/111394/1...  179.00    5万+
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=5550, step=1)

# %%
data.columns
# Out:
# Index(['搜索关键词', '商品名称', '商品SKU', '商品链接', '封面图链接', '价格', '评价人数', '评论链接', '商家店名',
#        '店铺链接', '标签', '是否广告', '页码', '当前时间', '页面网址'],
#       dtype='object')

# %%
data.values
# Out:
# array([['跑步鞋',
#         '特步男鞋运动鞋子男夏季网面鞋透气减震新款跑步鞋跑鞋休闲鞋男运动鞋包 白灰绿 42\n\t\t\t\t\t\t\t\t晒图3张返3元',
#         10030884795783, ..., 1.0, '2022-06-15 08:57:14',
#         'https://search.jd.com/Search?keyword=%E8%B7%91%E6%AD%A5%E9%9E%8B&enc=utf-8&wq=%E8%B7%91%E6%AD%A5%E9%9E%8B&pvid=8a2cd222928d4c4aa97b4a4ab607fce7'],
#        ['跑步鞋',
#         '鸿星尔克男鞋红星运动鞋男2022春夏季新款飞织透气网面皮革防水保暖舒适男士跑步鞋学生潮流休闲鞋子男冬 正白/浅灰(飞织) 42\n\t\t\t\t\t\t\t\t【夏季尚新】燃动国货夏季新款上市丨爆款直降低至3折起丨正品保证，防伪码可查！点击查看热销清单！',
#         10028835246963, ..., 1.0, '2022-06-15 08:57:15',
#         'https://search.jd.com/Search?keyword=%E8%B7%91%E6%AD%A5%E9%9E%8B&enc=utf-8&wq=%E8%B7%91%E6%AD%A5%E9%9E%8B&pvid=8a2cd222928d4c4aa97b4a4ab607fce7'],
#        ['跑步鞋',
#         '【氢风科技】特步男鞋运动鞋子男夏季新款跑步鞋透气网面飞织潮流男士旅游防滑耐磨健身训练网鞋休闲超轻跑鞋 白色【店长推荐】 42\n\t\t\t\t\t\t\t\t【氢风科技】特步男鞋运动鞋子男夏季新款跑步鞋透气网面飞织潮流男士旅游防滑耐磨健身训练网鞋休闲超轻跑鞋 白色【店长推荐】 42',
#         10044043233367, ..., 1.0, '2022-06-15 08:57:15',
# ...

# %%
data.T
# Out:
#                                                     0     \
# 搜索关键词                                                跑步鞋
# 商品名称   特步男鞋运动鞋子男夏季网面鞋透气减震新款跑步鞋跑鞋休闲鞋男运动鞋包 白灰绿 42\n\t\t...
# 商品SKU                                     10030884795783
# 商品链接             https://item.jd.com/10030884795783.html
# 封面图链接  https://img13.360buyimg.com/n7/jfs/t1/192406/3...
# 价格                                                139.00
# 评价人数                                                 5万+
# 评论链接     https://item.jd.com/10030884795783.html#comment
# 商家店名                                             特步沃冠专卖店
# 店铺链接     https://mall.jd.com/index-10086398.html?from=pc
# 标签     京东物流\n\t\t\t\t\t\t\t\t跨店每满299-50\n\t\t\t\t\t\t...
# 是否广告                                                   否
# 页码                                                     1
# 当前时间                                 2022-06-15 08:57:14
# 页面网址   https://search.jd.com/Search?keyword=%E8%B7%91...
#
# ...

# %%
y=data['价格']
y
# Out:
# 0        139.00
# 1        179.00
# 2        159.00
# 3        229.00
# 4        198.00
#          ...
# 5545     999.00
# 5546    4299.00
# 5547    3999.00
# 5548    7049.00
# 5549    8999.00
# Name: 价格, Length: 5550, dtype: object

# %%
x=data['评价人数']
x
# Out:
# 0         5万+
# 1         5万+
# 2         1万+
# 3        10万+
# 4       1000+
#         ...
# 5545      1万+
# 5546      2万+
# 5547     200+
# 5548      1万+
# 5549    1000+
# Name: 评价人数, Length: 5550, dtype: object
